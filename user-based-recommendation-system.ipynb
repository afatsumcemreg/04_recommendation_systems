# %% [markdown]
# # Developing a User-Based Recommendation System using the Datasets 'Movie and Rating'
#
# # Business problem
#
# ### An online movie viewing platform wants to improve its recommendation system. Trying out content and product-based recommendation systems, the company wants users to be more customizable. Suggestions have been made according to similar liking structures for movies, but they want to customize these general suggestions more based on the similarity of the users to the users.
#
# # Dataset story
#
# ### The data set is provided by the mobile lens, it contains the movies and the scores given to these movies. The dataset contains more than 20000000 ratings for approximately 27000 movies per hour.
#
# # Variables
#
# ### There are many different tables in this dataset, but there are 2 CSV files to use.
#
# #### movie.csv
# * movieId - Unique movie number
# * title - movie name
#
# #### rating.csv
# * userid - Unique user number
# * movieId - Unique movie number
# * rating - the rating given to the movie by the user
# * timestamp - review date

# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd

# %% [markdown]
# # Reading and preparing the dataset

# %% [markdown]
# ### Let's define the 'create_user_movie_df' function to prepare the dataset

# %%
def create_user_movie_df():
    import pandas as pd
    rating = pd.read_csv('/kaggle/input/movie-rating/rating.csv')
    movie = pd.read_csv('/kaggle/input/movie-rating/movie.csv')
    df = movie.merge(rating, how='left', on='movieId')
    df.columns = [col.lower() for col in df.columns]
    comment_counts = pd.DataFrame(df.title.value_counts())
    rare_movies = comment_counts[comment_counts['title'] <= 1000].index
    common_movies = df[~df['title'].isin(rare_movies)]
    user_movie_df = common_movies.pivot_table(index=['userid'], columns=['title'], values='rating')
    return user_movie_df

user_movie_df = create_user_movie_df()

# %%
user_movie_df.head()
# Out:
# title   'burbs, The (1989)  (500) Days of Summer (2009)  \
# userid
# 1.0                    NaN                          NaN
# 2.0                    NaN                          NaN
# 3.0                    NaN                          NaN
# 4.0                    NaN                          NaN
# 5.0                    NaN                          NaN
#
# title   *batteries not included (1987)  ...And Justice for All (1979)  \
# userid
# 1.0                                NaN                            NaN
# 2.0                                NaN                            NaN
# 3.0                                NaN                            NaN
# 4.0                                NaN                            NaN
# 5.0                                NaN                            NaN
#
# title   10 Things I Hate About You (1999)  10,000 BC (2008)  \
# userid
# 1.0                                   NaN               NaN
# 2.0                                   NaN               NaN
# 3.0                                   NaN               NaN
# 4.0                                   NaN               NaN
# 5.0                                   NaN               NaN
#
# title   101 Dalmatians (1996)  \
# userid
# 1.0                       NaN
# 2.0                       NaN
# 3.0                       NaN
# 4.0                       NaN
# 5.0                       NaN
#
# title   101 Dalmatians (One Hundred and One Dalmatians) (1961)  \
# userid
# 1.0                                                   NaN
# 2.0                                                   NaN
# 3.0                                                   NaN
# 4.0                                                   NaN
# 5.0                                                   NaN
#
# title   102 Dalmatians (2000)  12 Angry Men (1957)  ...  \
# userid                                              ...
# 1.0                       NaN                  NaN  ...
# 2.0                       NaN                  NaN  ...
# 3.0                       NaN                  NaN  ...
# 4.0                       NaN                  NaN  ...
# 5.0                       NaN                  NaN  ...
#
# title   Zero Dark Thirty (2012)  Zero Effect (1998)  Zodiac (2007)  \
# userid
# 1.0                         NaN                 NaN            NaN
# 2.0                         NaN                 NaN            NaN
# 3.0                         NaN                 NaN            NaN
# 4.0                         NaN                 NaN            NaN
# 5.0                         NaN                 NaN            NaN
#
# title   Zombieland (2009)  Zoolander (2001)  Zulu (1964)  [REC] (2007)  \
# userid
# 1.0                   NaN               NaN          NaN           NaN
# 2.0                   NaN               NaN          NaN           NaN
# 3.0                   NaN               NaN          NaN           NaN
# 4.0                   NaN               NaN          NaN           NaN
# 5.0                   NaN               NaN          NaN           NaN
#
# title   eXistenZ (1999)  xXx (2002)  ¡Three Amigos! (1986)
# userid
# 1.0                 NaN         NaN                    NaN
# 2.0                 NaN         NaN                    NaN
# 3.0                 NaN         NaN                    NaN
# 4.0                 NaN         NaN                    NaN
# 5.0                 NaN         NaN                    NaN
#
# [5 rows x 3159 columns]

# %% [markdown]
# ### Let'select a random user

# %%
random_user = int(pd.Series(user_movie_df.index).sample(1).values)
random_user
# Out:
# 47509

# %% [markdown]
# # Application to get the watched movies

# %% [markdown]
# ### Our other purpose after this point is to determine which movies were watched by the random user selected.

# %%
random_user_df = user_movie_df[user_movie_df.index == random_user]
movies_watched = random_user_df.columns[random_user_df.notna().any()].tolist()
movies_watched
# Out:
# ['Birdcage, The (1996)',
#  'Broken Arrow (1996)',
#  'Eraser (1996)',
#  'Fargo (1996)',
#  'Father of the Bride Part II (1995)',
#  'Grumpier Old Men (1995)',
#  'Happy Gilmore (1996)',
#  'Heat (1995)',
#  'Independence Day (a.k.a. ID4) (1996)',
#  'Mission: Impossible (1996)',
#  'Nutty Professor, The (1996)',
#  'Phenomenon (1996)',
#  'Primal Fear (1996)',
#  'Rock, The (1996)',
#  'Sabrina (1995)',
#  'Star Trek: First Contact (1996)',
#  'Star Wars: Episode IV - A New Hope (1977)',
#  'Star Wars: Episode VI - Return of the Jedi (1983)',
#  'Toy Story (1995)',
#  'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)',
#  'Twister (1996)',
#  'Willy Wonka & the Chocolate Factory (1971)']

# %% [markdown]
# ### Let's get the number of the movies watched by the user

# %%
print(f'The number of the movies watched by the user is {len(movies_watched)}')
# Out:
# The number of the movies watched by the user is 22

# %% [markdown]
# ### So, we got the movies watched and the number by the selected random user.

# %% [markdown]
# ### Now, let's validate the movies watched by the user selected

# %%
user_movie_df.loc[user_movie_df.index == random_user, user_movie_df.columns == 'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)']
# Out:
# title    Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# userid
# 47509.0                                        4.0

# %% [markdown]
# ### As you see that the user watched the movie named 'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)'

# %% [markdown]
# # Getting other users wathching the same movies

# %%
movies_watched_df = user_movie_df[movies_watched]
movies_watched_df
# Out:
# title     Birdcage, The (1996)  Broken Arrow (1996)  Eraser (1996)  \
# userid
# 1.0                        NaN                  NaN            NaN
# 2.0                        NaN                  NaN            NaN
# 3.0                        NaN                  NaN            NaN
# 4.0                        NaN                  NaN            NaN
# 5.0                        5.0                  NaN            NaN
# ...                        ...                  ...            ...
# 138489.0                   NaN                  NaN            NaN
# 138490.0                   NaN                  NaN            NaN
# 138491.0                   NaN                  NaN            NaN
# 138492.0                   NaN                  NaN            NaN
# 138493.0                   NaN                  NaN            NaN
#
# title     Fargo (1996)  Father of the Bride Part II (1995)  \
# userid
# 1.0                NaN                                 NaN
# 2.0                NaN                                 NaN
# 3.0                NaN                                 NaN
# 4.0                NaN                                 NaN
# 5.0                3.0                                 NaN
# ...                ...                                 ...
# 138489.0           NaN                                 NaN
# 138490.0           NaN                                 NaN
# 138491.0           NaN                                 NaN
# 138492.0           NaN                                 NaN
# 138493.0           NaN                                 NaN
#
# title     Grumpier Old Men (1995)  Happy Gilmore (1996)  Heat (1995)  \
# userid
# 1.0                           NaN                   NaN          NaN
# 2.0                           4.0                   NaN          NaN
# 3.0                           NaN                   NaN          NaN
# 4.0                           NaN                   NaN          3.0
# 5.0                           NaN                   2.0          NaN
# ...                           ...                   ...          ...
# 138489.0                      NaN                   NaN          NaN
# 138490.0                      NaN                   NaN          NaN
# 138491.0                      NaN                   NaN          NaN
# 138492.0                      NaN                   NaN          NaN
# 138493.0                      NaN                   NaN          NaN
#
# title     Independence Day (a.k.a. ID4) (1996)  Mission: Impossible (1996)  \
# userid
# 1.0                                        NaN                         NaN
# 2.0                                        NaN                         NaN
# 3.0                                        3.0                         NaN
# 4.0                                        NaN                         NaN
# 5.0                                        5.0                         3.0
# ...                                        ...                         ...
# 138489.0                                   NaN                         NaN
# 138490.0                                   NaN                         NaN
# 138491.0                                   NaN                         NaN
# 138492.0                                   NaN                         NaN
# 138493.0                                   4.0                         NaN
#
# title     ...  Primal Fear (1996)  Rock, The (1996)  Sabrina (1995)  \
# userid    ...
# 1.0       ...                 NaN               NaN             NaN
# 2.0       ...                 NaN               NaN             NaN
# 3.0       ...                 NaN               NaN             NaN
# 4.0       ...                 NaN               5.0             NaN
# 5.0       ...                 NaN               NaN             NaN
# ...       ...                 ...               ...             ...
# 138489.0  ...                 NaN               NaN             NaN
# 138490.0  ...                 NaN               NaN             NaN
# 138491.0  ...                 NaN               NaN             NaN
# 138492.0  ...                 NaN               NaN             NaN
# 138493.0  ...                 NaN               NaN             NaN
#
# title     Star Trek: First Contact (1996)  \
# userid
# 1.0                                   NaN
# 2.0                                   5.0
# 3.0                                   5.0
# 4.0                                   NaN
# 5.0                                   NaN
# ...                                   ...
# 138489.0                              NaN
# 138490.0                              NaN
# 138491.0                              NaN
# 138492.0                              NaN
# 138493.0                              NaN
#
# title     Star Wars: Episode IV - A New Hope (1977)  \
# userid
# 1.0                                             4.0
# 2.0                                             5.0
# 3.0                                             5.0
# 4.0                                             NaN
# 5.0                                             5.0
# ...                                             ...
# 138489.0                                        NaN
# 138490.0                                        NaN
# 138491.0                                        NaN
# 138492.0                                        NaN
# 138493.0                                        4.5
#
# title     Star Wars: Episode VI - Return of the Jedi (1983)  Toy Story (1995)  \
# userid
# 1.0                                                     NaN               NaN
# 2.0                                                     5.0               NaN
# 3.0                                                     5.0               4.0
# 4.0                                                     NaN               NaN
# 5.0                                                     5.0               NaN
# ...                                                     ...               ...
# 138489.0                                                NaN               NaN
# 138490.0                                                NaN               NaN
# 138491.0                                                NaN               2.0
# 138492.0                                                NaN               NaN
# 138493.0                                                5.0               3.5
#
# title     Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Twister (1996)  \
# userid
# 1.0                                             3.5             NaN
# 2.0                                             NaN             NaN
# 3.0                                             4.0             NaN
# 4.0                                             1.0             NaN
# 5.0                                             NaN             5.0
# ...                                             ...             ...
# 138489.0                                        NaN             NaN
# 138490.0                                        5.0             NaN
# 138491.0                                        NaN             NaN
# 138492.0                                        NaN             NaN
# 138493.0                                        NaN             NaN
#
# title     Willy Wonka & the Chocolate Factory (1971)
# userid
# 1.0                                              NaN
# 2.0                                              NaN
# 3.0                                              5.0
# 4.0                                              NaN
# 5.0                                              2.0
# ...                                              ...
# 138489.0                                         NaN
# 138490.0                                         NaN
# 138491.0                                         NaN
# 138492.0                                         3.5
# 138493.0                                         5.0
#
# [138493 rows x 22 columns]

# %% [markdown]
# ### So, we have information regarding only the watched movies by the user and customized in terms of the user by reducing the dataset.

# %% [markdown]
# ### Let's reduce the data to users who watch at least 60% of the movies together with the user by setting a threshold value
# ### It doesn't make sense for people who have watched at least one common movie to stay in the dataset, because we can't catch a relationship from here.
# ### Therefore, users who watch more than a certain number of joint movies should be caught.

# %% [markdown]
# ### Let's determine how many movies each user in the dataset (movies_watched_df) has watched

# %%
user_movie_count = movies_watched_df.T.notnull().sum()
user_movie_count
# Out:
# userid
# 1.0          2
# 2.0          4
# 3.0          8
# 4.0          3
# 5.0         10
#             ..
# 138489.0     0
# 138490.0     1
# 138491.0     1
# 138492.0     1
# 138493.0     6
# Length: 138493, dtype: int64

# %% [markdown]
# ### Since the 'userid' in the index will be processed, it must be converted to a variable.

# %%
user_movie_count = user_movie_count.reset_index()
user_movie_count
# Out:
#           userid   0
# 0            1.0   2
# 1            2.0   4
# 2            3.0   8
# 3            4.0   3
# 4            5.0  10
# ...          ...  ..
# 138488  138489.0   0
# 138489  138490.0   1
# 138490  138491.0   1
# 138491  138492.0   1
# 138492  138493.0   6
#
# [138493 rows x 2 columns]

# %% [markdown]
# ### let's rename the variables

# %%
user_movie_count.columns = ['userid', 'movie_count']
user_movie_count
# Out:
#           userid  movie_count
# 0            1.0            2
# 1            2.0            4
# 2            3.0            8
# 3            4.0            3
# 4            5.0           10
# ...          ...          ...
# 138488  138489.0            0
# 138489  138490.0            1
# 138490  138491.0            1
# 138491  138492.0            1
# 138492  138493.0            6
#
# [138493 rows x 2 columns]

# %% [markdown]
# ### Let's bring users who watched more than 60 percent of movies in partnership with the user

# %%
percent = len(movies_watched) * 0.6
user_same_movies = user_movie_count[user_movie_count['movie_count'] > percent]['userid']
user_same_movies
# Out:
# 11            12.0
# 18            19.0
# 23            24.0
# 53            54.0
# 68            69.0
#             ...
# 138386    138387.0
# 138396    138397.0
# 138410    138411.0
# 138473    138474.0
# 138479    138480.0
# Name: userid, Length: 9930, dtype: float64

# %% [markdown]
# ### Let's access the number of users who watched all the movies the user watched

# %%
user_movie_count[user_movie_count['movie_count'] == len(movies_watched)].count()
# Out:
# userid         205
# movie_count    205
# dtype: int64

# %% [markdown]
# # Determination of similarities
#
# ### Goal: to identify users with the most similar behavior to the selected user
# ### This process can be performed in three stages
# * Aggregating user and other users' data
# * Creating the correlation dataframe
# * Finding the most similar users (top_users)

# %% [markdown]
# ### Stage 1: Aggregating user and other users' data

# %%
final_df = pd.concat([movies_watched_df[movies_watched_df.index.isin(user_same_movies)], random_user_df[movies_watched]])
final_df
# Out:
# title     Birdcage, The (1996)  Broken Arrow (1996)  Eraser (1996)  \
# userid
# 12.0                       NaN                  3.0            4.0
# 19.0                       5.0                  3.0            4.0
# 24.0                       NaN                  4.0            NaN
# 54.0                       NaN                  2.0            4.0
# 69.0                       NaN                  3.0            3.0
# ...                        ...                  ...            ...
# 138397.0                   2.0                  NaN            4.5
# 138411.0                   3.5                  3.0            2.5
# 138474.0                   4.0                  4.0            5.0
# 138480.0                   3.0                  3.0            4.0
# 47509.0                    4.0                  3.0            3.0
#
# title     Fargo (1996)  Father of the Bride Part II (1995)  \
# userid
# 12.0               5.0                                 2.0
# 19.0               5.0                                 NaN
# 24.0               2.0                                 2.0
# 54.0               5.0                                 3.0
# 69.0               3.0                                 3.0
# ...                ...                                 ...
# 138397.0           4.0                                 NaN
# 138411.0           4.0                                 NaN
# 138474.0           NaN                                 4.0
# 138480.0           NaN                                 NaN
# 47509.0            4.0                                 4.0
#
# title     Grumpier Old Men (1995)  Happy Gilmore (1996)  Heat (1995)  \
# userid
# 12.0                          3.0                   4.0          3.0
# 19.0                          4.0                   NaN          5.0
# 24.0                          NaN                   5.0          4.0
# 54.0                          NaN                   NaN          3.0
# 69.0                          NaN                   3.0          4.0
# ...                           ...                   ...          ...
# 138397.0                      5.0                   4.5          5.0
# 138411.0                      NaN                   2.5          5.0
# 138474.0                      NaN                   5.0          5.0
# 138480.0                      3.0                   4.0          NaN
# 47509.0                       4.0                   3.0          4.0
#
# title     Independence Day (a.k.a. ID4) (1996)  Mission: Impossible (1996)  \
# userid
# 12.0                                       3.0                         3.0
# 19.0                                       4.0                         3.0
# 24.0                                       4.0                         4.0
# 54.0                                       5.0                         3.0
# 69.0                                       4.0                         4.0
# ...                                        ...                         ...
# 138397.0                                   5.0                         4.0
# 138411.0                                   2.5                         2.5
# 138474.0                                   NaN                         4.0
# 138480.0                                   4.0                         4.0
# 47509.0                                    3.0                         4.0
#
# title     ...  Primal Fear (1996)  Rock, The (1996)  Sabrina (1995)  \
# userid    ...
# 12.0      ...                 NaN               4.0             3.0
# 19.0      ...                 4.0               4.0             5.0
# 24.0      ...                 NaN               4.0             3.0
# 54.0      ...                 NaN               4.0             NaN
# 69.0      ...                 NaN               4.0             NaN
# ...       ...                 ...               ...             ...
# 138397.0  ...                 NaN               5.0             NaN
# 138411.0  ...                 NaN               4.0             NaN
# 138474.0  ...                 NaN               5.0             NaN
# 138480.0  ...                 NaN               5.0             NaN
# 47509.0   ...                 4.0               4.0             3.0
#
# title     Star Trek: First Contact (1996)  \
# userid
# 12.0                                  NaN
# 19.0                                  NaN
# 24.0                                  3.0
# 54.0                                  5.0
# 69.0                                  5.0
# ...                                   ...
# 138397.0                              3.5
# 138411.0                              4.5
# 138474.0                              5.0
# 138480.0                              4.0
# 47509.0                               3.0
#
# title     Star Wars: Episode IV - A New Hope (1977)  \
# userid
# 12.0                                            4.0
# 19.0                                            NaN
# 24.0                                            5.0
# 54.0                                            4.0
# 69.0                                            5.0
# ...                                             ...
# 138397.0                                        3.5
# 138411.0                                        5.0
# 138474.0                                        5.0
# 138480.0                                        4.0
# 47509.0                                         5.0
#
# title     Star Wars: Episode VI - Return of the Jedi (1983)  Toy Story (1995)  \
# userid
# 12.0                                                    NaN               4.0
# 19.0                                                    NaN               5.0
# 24.0                                                    5.0               4.0
# 54.0                                                    3.0               4.0
# 69.0                                                    5.0               4.0
# ...                                                     ...               ...
# 138397.0                                                3.5               NaN
# 138411.0                                                5.0               5.0
# 138474.0                                                5.0               5.0
# 138480.0                                                NaN               4.0
# 47509.0                                                 4.0               4.0
#
# title     Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Twister (1996)  \
# userid
# 12.0                                            3.0             3.0
# 19.0                                            2.0             4.0
# 24.0                                            4.0             NaN
# 54.0                                            5.0             4.0
# 69.0                                            5.0             3.0
# ...                                             ...             ...
# 138397.0                                        4.5             NaN
# 138411.0                                        5.0             2.0
# 138474.0                                        5.0             NaN
# 138480.0                                        4.0             4.0
# 47509.0                                         4.0             3.0
#
# title     Willy Wonka & the Chocolate Factory (1971)
# userid
# 12.0                                             NaN
# 19.0                                             5.0
# 24.0                                             2.0
# 54.0                                             3.0
# 69.0                                             4.0
# ...                                              ...
# 138397.0                                         3.5
# 138411.0                                         5.0
# 138474.0                                         5.0
# 138480.0                                         3.0
# 47509.0                                          5.0
#
# [9931 rows x 22 columns]

# %% [markdown]
# ### Stage 2: Creating the correlation dataframe

# %% [markdown]
# ### Let's transport the users to variables to calculate the correlations.

# %%
corr_df = final_df.T.corr().unstack().sort_values().drop_duplicates()
corr_df
# Out:
# userid    userid
# 136696.0  66208.0    -1.0
# 65379.0   78200.0    -1.0
# 57176.0   83858.0    -1.0
# 49766.0   115050.0   -1.0
# 10635.0   108403.0   -1.0
#                      ...
# 12435.0   43820.0     1.0
# 138480.0  138480.0    1.0
# 25460.0   29553.0     1.0
# 18101.0   66208.0     1.0
# 12.0      3052.0      NaN
# Length: 14261534, dtype: float64

# %% [markdown]
# ### Let's do the following to better read the price

# %%
corr_df = pd.DataFrame(corr_df, columns=['corr'])
corr_df.index.names = ['user_id_1', 'user_id_2']
corr_df = corr_df.reset_index()
corr_df
# Out:
#           user_id_1  user_id_2  corr
# 0          136696.0    66208.0  -1.0
# 1           65379.0    78200.0  -1.0
# 2           57176.0    83858.0  -1.0
# 3           49766.0   115050.0  -1.0
# 4           10635.0   108403.0  -1.0
# ...             ...        ...   ...
# 14261529    12435.0    43820.0   1.0
# 14261530   138480.0   138480.0   1.0
# 14261531    25460.0    29553.0   1.0
# 14261532    18101.0    66208.0   1.0
# 14261533       12.0     3052.0   NaN
#
# [14261534 rows x 3 columns]

# %% [markdown]
# ### Stage 3: Finding the most similar users (top_users)

# %% [markdown]
# ### Let's get users who have 65% or more correlation with the user and call them 'top_user'

# %%
top_users = corr_df[(corr_df['user_id_1'] == random_user) & (corr_df['corr'] >= 0.65)][['user_id_2', 'corr']].reset_index(drop=True).sort_values('corr', ascending=False)
top_users
# Out:
#      user_id_2      corr
# 171    91740.0  0.937229
# 170    96849.0  0.872742
# 169    76435.0  0.854592
# 168    80677.0  0.832424
# 167    84374.0  0.824160
# ..         ...       ...
# 4      49936.0  0.651595
# 3      29598.0  0.651463
# 2      14285.0  0.650985
# 1      92636.0  0.650380
# 0      75939.0  0.650167
#
# [172 rows x 2 columns]

# %% [markdown]
# ### Since we do not have the information of how many points these users gave to which movie, let's combine the rating file with the tup_users data to find out.

# %% [markdown]
# ### First, let's change the iser_id_2 to userId

# %%
top_users.rename(columns = {'user_id_2': 'userId'}, inplace=True)

# %%
rating = pd.read_csv('/kaggle/input/movie-rating/rating.csv')
top_users_rating = top_users.merge(rating[['userId', 'movieId', 'rating']], how='inner')
top_users_rating
# Out:
#          userId      corr  movieId  rating
# 0       91740.0  0.937229        1     3.5
# 1       91740.0  0.937229        6     3.0
# 2       91740.0  0.937229       10     2.5
# 3       91740.0  0.937229       16     3.5
# 4       91740.0  0.937229       19     2.0
# ...         ...       ...      ...     ...
# 126207  75939.0  0.650167    31747     1.0
# 126208  75939.0  0.650167    33493     4.5
# 126209  75939.0  0.650167    33794     5.0
# 126210  75939.0  0.650167    35836     4.5
# 126211  75939.0  0.650167    39292     5.0
#
# [126212 rows x 4 columns]

# %%
top_users_rating = top_users_rating[top_users_rating['userId'] != random_user]
top_users_rating
# Out:
#          userId      corr  movieId  rating
# 0       91740.0  0.937229        1     3.5
# 1       91740.0  0.937229        6     3.0
# 2       91740.0  0.937229       10     2.5
# 3       91740.0  0.937229       16     3.5
# 4       91740.0  0.937229       19     2.0
# ...         ...       ...      ...     ...
# 126207  75939.0  0.650167    31747     1.0
# 126208  75939.0  0.650167    33493     4.5
# 126209  75939.0  0.650167    33794     5.0
# 126210  75939.0  0.650167    35836     4.5
# 126211  75939.0  0.650167    39292     5.0
#
# [126212 rows x 4 columns]

# %% [markdown]
# ### As a result, users with the highest correlation with the user and their scores for various movies were obtained. The scores given to each movie by the users who watched at least 60% of the movies in common with the user and the correlations of these users were calculated.

# %% [markdown]
# # Score calculation

# %% [markdown]
# ### Let's calculate the weighted average recommendation score. To make this, let's consider both correlation score and rating score. Therefore, we can evaluate the effect of the correlation and rating at the same moment.

# %%
top_users_rating['weighted_rating'] = top_users_rating['corr'] * top_users_rating['rating']
top_users_rating.sort_values('weighted_rating', ascending=False).head()
# Out:
#       userId      corr  movieId  rating  weighted_rating
# 112  91740.0  0.937229     1196     5.0         4.686146
# 31   91740.0  0.937229      260     5.0         4.686146
# 486  91740.0  0.937229     7118     5.0         4.686146
# 282  91740.0  0.937229     2712     5.0         4.686146
# 407  91740.0  0.937229     4825     5.0         4.686146

# %% [markdown]
# ### As you see that for the movieId variable, same user gave many ratings. Therefore, if we perform the groupby operation according to the movieId variable and take the average of the weighted_rating variable, then our final values will be revealed.

# %%
recommendation_df = top_users_rating.groupby('movieId').agg({'weighted_rating': 'mean'}).sort_values('weighted_rating', ascending=False)
recommendation_df = recommendation_df.reset_index()
recommendation_df
# Out:
#       movieId  weighted_rating
# 0       26701         4.686146
# 1       47836         4.686146
# 2       53002         4.059863
# 3       59143         4.059863
# 4       51007         3.970387
# ...       ...              ...
# 9574   108689         0.328150
# 9575    89041         0.328150
# 9576     7002         0.328150
# 9577    27136         0.328150
# 9578     2835         0.327541
#
# [9579 rows x 2 columns]

# %% [markdown]
# ### We can filter the weighted_rating variable to bring the movies that the user may like.For example, those with a value of weighted_rating greater than 3.5 can be movies that the user will like.

# %%
movies_to_be_recommended = recommendation_df[recommendation_df['weighted_rating'] > 3.5]
movies_to_be_recommended
# Out:
#     movieId  weighted_rating
# 0     26701         4.686146
# 1     47836         4.686146
# 2     53002         4.059863
# 3     59143         4.059863
# 4     51007         3.970387
# 5     27357         3.970387
# 6       583         3.970387
# 7      2830         3.970387
# 8     31705         3.970387
# 9       864         3.970387
# 10       59         3.970387
# 11     3876         3.970387
# 12     2593         3.970387
# 13     7475         3.903339
# 14    61312         3.748917
# 15    31930         3.748917
# 16     7789         3.660009
# 17     8488         3.654154
# 18     6526         3.653876
# 19    98122         3.653876
# 20    90863         3.653876
# 21   101106         3.653876
# 22     8574         3.644025
# 23     5297         3.644025
# 24     1545         3.625942
# 25     6945         3.622469
# 26    26465         3.620263
# 27    27738         3.617735
# 28    57543         3.617735
# 29    74731         3.617735
# 30     8195         3.599160
# 31    68536         3.585439
# 32    78544         3.582219
# 33    78160         3.582219
# 34    78162         3.582219
# 35    83506         3.582219
# 36     6210         3.573348
# 37    83796         3.573348
# 38     1861         3.573348
# 39    47394         3.573348
# 40     4272         3.573348
# 41    80328         3.568268
# 42    80315         3.568268
# 43    26873         3.568268
# 44    36630         3.568268
# 45     7295         3.560181
# 46     1574         3.546626
# 47    27156         3.541157
# 48     7566         3.540622
# 49     7306         3.531835
# 50     7940         3.520763
# 51     2557         3.513492
# 52     6818         3.511333

# %% [markdown]
# ### So, we can recommend only 5 movies to the selected user that being a weighted_rating higher than 3.5

# %% [markdown]
# ### Let's determine which movies are recommended movies

# %%
movie = pd.read_csv('/kaggle/input/movie-rating/movie.csv')
movies_to_be_recommended = movies_to_be_recommended.merge(movie[['movieId', 'title']])
movies_to_be_recommended
# Out:
#     movieId  weighted_rating  \
# 0     26701         4.686146
# 1     47836         4.686146
# 2     53002         4.059863
# 3     59143         4.059863
# 4     51007         3.970387
# 5     27357         3.970387
# 6       583         3.970387
# 7      2830         3.970387
# 8     31705         3.970387
# 9       864         3.970387
# 10       59         3.970387
# 11     3876         3.970387
# 12     2593         3.970387
# 13     7475         3.903339
# 14    61312         3.748917
# 15    31930         3.748917
# 16     7789         3.660009
# 17     8488         3.654154
# 18     6526         3.653876
# 19    98122         3.653876
# 20    90863         3.653876
# 21   101106         3.653876
# 22     8574         3.644025
# 23     5297         3.644025
# 24     1545         3.625942
# 25     6945         3.622469
# 26    26465         3.620263
# 27    27738         3.617735
# 28    57543         3.617735
# 29    74731         3.617735
# 30     8195         3.599160
# 31    68536         3.585439
# 32    78544         3.582219
# 33    78160         3.582219
# 34    78162         3.582219
# 35    83506         3.582219
# 36     6210         3.573348
# 37    83796         3.573348
# 38     1861         3.573348
# 39    47394         3.573348
# 40     4272         3.573348
# 41    80328         3.568268
# 42    80315         3.568268
# 43    26873         3.568268
# 44    36630         3.568268
# 45     7295         3.560181
# 46     1574         3.546626
# 47    27156         3.541157
# 48     7566         3.540622
# 49     7306         3.531835
# 50     7940         3.520763
# 51     2557         3.513492
# 52     6818         3.511333
#
#                                                 title
# 0   Patlabor: The Movie (Kidô keisatsu patorebâ: T...
# 1                      Sketches of Frank Gehry (2005)
# 2                                 Georgia Rule (2007)
# 3                                Super High Me (2007)
# 4                    Days of Glory (Indigènes) (2006)
# 5   Old Men in New Cars (Gamle mænd i nye biler) (...
# 6                     Dear Diary (Caro Diario) (1994)
# 7                 Cabaret Balkan (Bure Baruta) (1998)
# 8                              Beautiful Boxer (2003)
# 9                                    Wife, The (1995)
# 10       Confessional, The (Confessionnal, Le) (1995)
# 11                               Jerry and Tom (1998)
# 12                   Monster, The (Mostro, Il) (1994)
# 13                                        Raid (2003)
# 14                                       Noise (2007)
# 15                            Masculin Féminin (1966)
# 16                  11'09\\"01 - September 11 (2002)"
# 17                                  Siddhartha (1972)
# 18  Rhapsody in August (Hachi-gatsu no kyôshikyoku...
# 19                       Indie Game: The Movie (2012)
# 20  George Harrison: Living in the Material World ...
# 21                                  Sound City (2013)
# 22         Claymation Christmas Celebration, A (1987)
# 23                             Cat's Meow, The (2002)
# 24                                     Ponette (1996)
# 25               My Architect: A Son's Journey (2003)
# 26                                    D.C. Cab (1983)
# 27                    Cathedral, The (Katedra) (2002)
# 28                Fallen Art (Sztuka spadania) (2004)
# 29                                    Eden Log (2007)
# 30              Avventura, L' (Adventure, The) (1960)
# 31         Stanley Kubrick: A Life in Pictures (2001)
# 32                  Ricky Gervais Live 3: Fame (2007)
# 33                 Ricky Gervais Live: Animals (2003)
# 34              Ricky Gervais Live 2: Politics (2004)
# 35               Ricky Gervais Live 4: Science (2010)
# 36                     Volcano High (Whasango) (2001)
# 37                Anything for Her (Pour elle) (2008)
# 38                    Junk Mail (Budbringeren) (1997)
# 39                            Bon Cop, Bad Cop (2006)
# 40                                      Tuvalu (1999)
# 41          Saimaa Gesture, The (Saimaa-ilmiö) (1981)
# 42                 Worthless, The (Arvottomat) (1982)
# 43  Take Care of Your Scarf, Tatiana (Pidä huivist...
# 44                          L.A. Without a Map (1998)
# 45                              After the Life (2002)
# 46                                        Fall (1997)
# 47  Neon Genesis Evangelion: The End of Evangelion...
# 48                                       28 Up (1985)
# 49            Herod's Law (Ley de Herodes, La) (2000)
# 50                    Magician, The (Ansiktet) (1958)
# 51            I Stand Alone (Seul contre tous) (1998)
# 52                 Come and See (Idi i smotri) (1985)

# %% [markdown]
# ### Consequently, we recommended to a user 5 movies based on the users.

# %% [markdown]
# # Thank you for checking my notebook!
